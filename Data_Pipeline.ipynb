# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
df = pd.read_csv('/Users/lilianmaina/Desktop/Projects/DataEngineeringProject/wfp_food_prices_ken.csv')
df
# Out:
#              date       admin1    admin2              market  market_id  \
# 0      2006-01-15        Coast   Mombasa             Mombasa        191
# 1      2006-01-15        Coast   Mombasa             Mombasa        191
# 2      2006-01-15      Eastern  Marsabit            Marsabit        190
# 3      2006-01-15      Nairobi   Nairobi             Nairobi        184
# 4      2006-01-15      Nairobi   Nairobi             Nairobi        184
# ...           ...          ...       ...                 ...        ...
# 17627  2025-11-15  Rift Valley   Turkana  Mogadishu (Kakuma)       3245
# 17628  2025-11-15  Rift Valley   Turkana  Mogadishu (Kakuma)       3245
# 17629  2025-11-15  Rift Valley   Turkana  Mogadishu (Kakuma)       3245
# 17630  2025-11-15  Rift Valley   Turkana  Mogadishu (Kakuma)       3245
# 17631  2025-11-15  Rift Valley   Turkana  Mogadishu (Kakuma)       3245
#
#        latitude  longitude               category        commodity  \
# 0         -4.05      39.67     cereals and tubers            Maize
# 1         -4.05      39.67        pulses and nuts            Beans
# 2          2.33      37.98     cereals and tubers    Maize (white)
# 3         -1.28      36.82     cereals and tubers            Bread
# 4         -1.28      36.82     cereals and tubers            Maize
# ...         ...        ...                    ...              ...
# 17627      3.72      34.85         milk and dairy       Milk (UHT)
# 17628      3.72      34.85     miscellaneous food            Sugar
# 17629      3.72      34.85           oil and fats  Oil (vegetable)
# 17630      3.72      34.85        pulses and nuts      Beans (dry)
# 17631      3.72      34.85  vegetables and fruits          Bananas
#
#        commodity_id    unit  priceflag  pricetype currency   price  usdprice
# 0                51      KG     actual  Wholesale      KES   16.13      0.22
# 1                50      KG     actual  Wholesale      KES   33.63      0.47
# 2                67      KG     actual     Retail      KES   21.00      0.29
# 3                55   400 G     actual     Retail      KES   26.00      0.36
# 4                51      KG     actual  Wholesale      KES   15.48      0.22
# ...             ...     ...        ...        ...      ...     ...       ...
# 17627           794  500 ML  aggregate     Retail      KES   80.00      0.62
# 17628            97      KG  aggregate     Retail      KES  169.72      1.31
# 17629            96       L  aggregate     Retail      KES  290.28      2.24
# 17630           262      KG  aggregate     Retail      KES  140.28      1.08
# 17631           254    Unit  aggregate     Retail      KES   20.00      0.15
#
# [17632 rows x 16 columns]

# %%
df.shape
# Out:
# (17632, 16)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17632 entries, 0 to 17631
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          17632 non-null  str
#  1   admin1        17585 non-null  str
#  2   admin2        17585 non-null  str
#  3   market        17632 non-null  str
#  4   market_id     17632 non-null  int64
#  5   latitude      17585 non-null  float64
#  6   longitude     17585 non-null  float64
#  7   category      17632 non-null  str
#  8   commodity     17632 non-null  str
#  9   commodity_id  17632 non-null  int64
#  10  unit          17632 non-null  str
#  11  priceflag     17632 non-null  str
#  12  pricetype     17632 non-null  str
#  13  currency      17632 non-null  str
#  14  price         17632 non-null  float64
#  15  usdprice      17632 non-null  float64
# dtypes: float64(4), int64(2), str(10)
# memory usage: 2.2 MB

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'market_id', 'latitude',
#        'longitude', 'category', 'commodity', 'commodity_id', 'unit',
#        'priceflag', 'pricetype', 'currency', 'price', 'usdprice'],
#       dtype='str')

# %%
df.head()
# Out:
#          date   admin1    admin2    market  market_id  latitude  longitude  \
# 0  2006-01-15    Coast   Mombasa   Mombasa        191     -4.05      39.67
# 1  2006-01-15    Coast   Mombasa   Mombasa        191     -4.05      39.67
# 2  2006-01-15  Eastern  Marsabit  Marsabit        190      2.33      37.98
# 3  2006-01-15  Nairobi   Nairobi   Nairobi        184     -1.28      36.82
# 4  2006-01-15  Nairobi   Nairobi   Nairobi        184     -1.28      36.82
#
#              category      commodity  commodity_id   unit priceflag  \
# 0  cereals and tubers          Maize            51     KG    actual
# 1     pulses and nuts          Beans            50     KG    actual
# 2  cereals and tubers  Maize (white)            67     KG    actual
# 3  cereals and tubers          Bread            55  400 G    actual
# 4  cereals and tubers          Maize            51     KG    actual
#
#    pricetype currency  price  usdprice
# 0  Wholesale      KES  16.13      0.22
# 1  Wholesale      KES  33.63      0.47
# 2     Retail      KES  21.00      0.29
# 3     Retail      KES  26.00      0.36
# 4  Wholesale      KES  15.48      0.22

# %%
df.isnull().sum()
# Out:
# date             0
# admin1          47
# admin2          47
# market           0
# market_id        0
# latitude        47
# longitude       47
# category         0
# commodity        0
# commodity_id     0
# unit             0
# priceflag        0
# pricetype        0
# currency         0
# price            0
# usdprice         0
# dtype: int64

# %%
engine = create_engine('mysql+pymysql://root:Hahaha!1!@localhost:3306/food_prices_ken')

# %%
df.to_sql(
  name = 'raw_food_prices',
  con = engine,
  if_exists = 'append',
  index = False
)
print('Successfully added and loaded to food_prices_ken db')
# Out:
# Successfully added and loaded to food_prices_ken db

# %%
sql_query = """
SELECT date, market, commodity, unit, price, currency
FROM raw_food_prices
WHERE admin1 = 'Nairobi'
ORDER BY date DESC
LIMIT 20; """

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
# Out:
#          date             market           commodity   unit    price currency
# 0  2025-10-15  Kangemi (Nairobi)    Beans (dolichos)  90 KG   5700.0      KES
# 1  2025-10-15  Kangemi (Nairobi)    Beans (dolichos)  90 KG   5700.0      KES
# 2  2025-10-15  Kangemi (Nairobi)    Beans (rosecoco)  90 KG  10300.0      KES
# 3  2025-10-15  Kangemi (Nairobi)    Beans (dolichos)  90 KG   5700.0      KES
# 4  2025-10-15  Kangemi (Nairobi)            Tomatoes  64 KG   2880.0      KES
# 5  2025-10-15  Kangemi (Nairobi)            Tomatoes  64 KG   2880.0      KES
# 6  2025-10-15  Kangemi (Nairobi)            Tomatoes  64 KG   2880.0      KES
# 7  2025-10-15  Kangemi (Nairobi)    Beans (rosecoco)  90 KG  10300.0      KES
# 8  2025-10-15  Kangemi (Nairobi)    Beans (rosecoco)  90 KG  10300.0      KES
# 9  2025-10-15  Kangemi (Nairobi)    Beans (dolichos)  90 KG   5700.0      KES
# 10 2025-10-15  Kangemi (Nairobi)            Tomatoes  64 KG   2880.0      KES
# 11 2025-10-15  Kangemi (Nairobi)    Beans (rosecoco)  90 KG  10300.0      KES
# 12 2025-10-15  Kangemi (Nairobi)    Beans (dolichos)  90 KG   5700.0      KES
# 13 2025-10-15  Kangemi (Nairobi)    Beans (dolichos)  90 KG   5700.0      KES
# 14 2025-10-15  Kangemi (Nairobi)    Beans (rosecoco)  90 KG  10300.0      KES
# 15 2025-10-15  Kangemi (Nairobi)            Tomatoes  64 KG   2880.0      KES
# 16 2025-10-15  Kangemi (Nairobi)    Beans (rosecoco)  90 KG  10300.0      KES
# 17 2025-10-15  Kangemi (Nairobi)            Tomatoes  64 KG   2880.0      KES
# 18 2025-08-15  Kangemi (Nairobi)  Maize (white, dry)  90 KG   4400.1      KES
# 19 2025-08-15  Kangemi (Nairobi)  Maize (white, dry)  90 KG   4400.1      KES

# %%
sql_query = """
SELECT commodity, 
	ROUND(AVG(price), 2) AS avg_price,
    MIN(price) AS min_price,
    MAX(price) AS max_price,
    COUNT(*) AS total_records
FROM raw_food_prices
GROUP BY commodity
ORDER BY avg_price DESC; """

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
# Out:
#                      commodity  avg_price  min_price  max_price  total_records
# 0               Beans (yellow)   10706.14    5400.00   18252.00           1602
# 1             Beans (dolichos)   10191.44    1500.00   17100.00            960
# 2                 Beans (mung)    9895.15    7200.00   12270.00            198
# 3             Beans (rosecoco)    9440.35    5850.00   19800.00            996
# 4                      Cowpeas    8604.62    2100.42   16200.00            960
# 5               Beans (kidney)    7490.53    1134.00   14850.00            474
# 6              Millet (finger)    7396.64    3600.00   11997.00            270
# 7              Sorghum (white)    5900.84    2700.00    8700.00            486
# 8    Rice (imported, Pakistan)    4931.47    3917.00    6305.00             90
# 9                Sorghum (red)    4847.07    3240.00    7200.00            306
# 10                    Tomatoes    3776.23     426.88   10628.48           2010
# 11                     Cabbage    3204.52      27.46   11970.00           1914
# 12     Potatoes (Irish, white)    2486.15     751.00    6120.00           1668
# 13                     Sorghum    2458.58      30.00    7470.00           4188
# 14                 Beans (dry)    2415.99      23.00   10000.00           6648
# 15       Potatoes (Irish, red)    2346.65     868.00    5310.00            762
# 16          Maize (white, dry)    2055.00      33.00    8128.00           3498
# 17             Rice (aromatic)    1986.30      87.00   10000.00           3630
# 18               Maize (white)    1104.95       8.00    4898.00           7296
# 19            Potatoes (Irish)    1061.69      35.00    5700.00           5484
# 20                        Kale     918.45       5.00    5000.00           3132
# 21                Onions (dry)     913.57     390.00    8100.00           2010
# 22                 Meat (goat)     615.20     400.00     881.25           1368
# 23                Meat (camel)     532.31     400.00     700.00            888
# 24                 Meat (beef)     531.91      10.00     800.00           1404
# 25  Oil (vegetable, fortified)     292.05     120.00     403.00           2748
# 26             Oil (vegetable)     238.66     115.00     400.00           3372
# 27           Pigeon peas (dry)     214.59     100.00     700.00            396
# 28                 Cooking fat     188.13     120.00     380.00            534
# 29               Cowpeas (dry)     163.63      50.00     310.00            900
# 30                       Sugar     158.67      90.36     305.00           5310
# 31           Fish (omena, dry)     156.69     130.00     198.00             78
# 32         Milk (camel, fresh)     136.08      50.00     280.00            426
# 33           Milk (cow, fresh)     123.96      60.00     203.89             96
# 34                        Rice     121.56      78.33     220.00           2124
# 35     Milk (cow, pasteurized)     121.01      20.00     280.00           2826
# 36                       Beans     105.66      28.23     270.00           6114
# 37      Fuel (petrol-gasoline)     102.12      83.33     118.11            264
# 38                 Wheat flour      98.69      50.00     174.00           4782
# 39         Maize flour (white)      96.13      46.00     195.00           2988
# 40               Fuel (diesel)      90.41      65.70     109.72            258
# 41                 Maize flour      81.30      50.00     137.80           2682
# 42                     Spinach      79.19      14.00     260.00           1104
# 43             Fuel (kerosene)      77.80      39.62     111.83            210
# 44                  Milk (UHT)      70.38      27.00     100.45           2472
# 45                       Bread      40.18      26.00      50.00            636
# 46                       Maize      39.29      10.43     120.00           6216
# 47               Cowpea leaves      32.02      10.00      87.00            162
# 48                     Bananas      14.19       5.00      21.67           2016
# 49                        Salt      12.19       8.24      55.00           4836

# %%
sql_query = """
SELECT commodity, COUNT(DISTINCT market) AS market_count -- REVIEW WITHOUT DISTINCT
FROM raw_food_prices
GROUP BY commodity
HAVING market_count > 10
ORDER BY market_count DESC;
"""

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
# Out:
#                      commodity  market_count
# 0                        Sugar           186
# 1              Rice (aromatic)           181
# 2                  Wheat flour           176
# 3                         Salt           173
# 4                        Beans           172
# 5          Maize flour (white)           170
# 6   Oil (vegetable, fortified)           161
# 7           Maize (white, dry)           155
# 8      Milk (cow, pasteurized)           153
# 9                         Kale           125
# 10                     Spinach            97
# 11               Cowpeas (dry)            85
# 12           Pigeon peas (dry)            48
# 13                 Beans (dry)            40
# 14            Potatoes (Irish)            37
# 15                     Cabbage            35
# 16                       Maize            35
# 17                 Maize flour            32
# 18                     Bananas            32
# 19                  Milk (UHT)            32
# 20                        Rice            32
# 21             Oil (vegetable)            31
# 22                     Sorghum            31
# 23                 Meat (beef)            28
# 24                 Meat (goat)            23
# 25                 Cooking fat            23
# 26                Onions (dry)            21
# 27                    Tomatoes            21
# 28              Beans (yellow)            19
# 29         Milk (camel, fresh)            19
# 30                Meat (camel)            17
# 31                     Cowpeas            17
# 32       Potatoes (Irish, red)            17
# 33     Potatoes (Irish, white)            17
# 34            Beans (rosecoco)            17
# 35              Beans (kidney)            17
# 36            Beans (dolichos)            16
# 37               Maize (white)            14
# 38               Sorghum (red)            14
# 39             Sorghum (white)            13
# 40             Millet (finger)            12
# 41                Beans (mung)            12
# 42           Milk (cow, fresh)            11

# %%
sql_query = """
SELECT admin2, EXTRACT(YEAR FROM date) AS year, ROUND(AVG(price), 2) as avg_price
FROM raw_food_prices
GROUP BY admin2, year
ORDER BY admin2, year;
"""

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
# Out:
#          admin2  year  avg_price
# 0           NaN  2015      38.50
# 1           NaN  2016      46.75
# 2           NaN  2017      60.76
# 3           NaN  2018      53.41
# 4           NaN  2019      56.26
# ..          ...   ...        ...
# 253       Wajir  2024     139.33
# 254       Wajir  2025     146.33
# 255  West Pokot  2021    4595.51
# 256  West Pokot  2022    4399.39
# 257  West Pokot  2023    5198.17
#
# [258 rows x 3 columns]

# %%
sql_query = """
SELECT date, admin2, market, commodity, price
FROM raw_food_prices
WHERE date >= '2025-01-01'
ORDER BY date DESC;
"""

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
# Out:
#            date   admin2                 market         commodity   price
# 0    2025-11-15  Garissa     Dagahaley (Daadab)       Maize flour   99.22
# 1    2025-11-15  Garissa     Dagahaley (Daadab)  Potatoes (Irish)   60.16
# 2    2025-11-15  Garissa     Dagahaley (Daadab)       Wheat flour   99.65
# 3    2025-11-15  Garissa     Dagahaley (Daadab)       Meat (goat)  881.25
# 4    2025-11-15  Garissa     Dagahaley (Daadab)        Milk (UHT)   52.23
# ...         ...      ...                    ...               ...     ...
# 8815 2025-01-15  Turkana  Kalobeyei (Village 3)        Milk (UHT)   77.50
# 8816 2025-01-15  Turkana  Kalobeyei (Village 3)              Salt   10.00
# 8817 2025-01-15  Turkana  Kalobeyei (Village 3)             Sugar  165.00
# 8818 2025-01-15  Turkana  Kalobeyei (Village 3)       Beans (dry)  130.00
# 8819 2025-01-15  Turkana  Kalobeyei (Village 3)           Bananas   20.00
#
# [8820 rows x 5 columns]

# %%
sql_query = """
SELECT commodity, pricetype, ROUND(AVG(price), 2) AS avg_price, COUNT(*) AS records
FROM raw_food_prices
GROUP BY commodity, pricetype
ORDER BY commodity, pricetype
"""

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
# Out:
#            commodity  pricetype  avg_price  records
# 0            Bananas     Retail      14.19     2016
# 1              Beans     Retail     159.68     2778
# 2              Beans  Wholesale      60.68     3336
# 3   Beans (dolichos)  Wholesale   10191.44      960
# 4        Beans (dry)     Retail     113.91     3984
# ..               ...        ...        ...      ...
# 56           Spinach     Retail      92.14      876
# 57           Spinach  Wholesale      29.42      228
# 58             Sugar     Retail     158.67     5310
# 59          Tomatoes  Wholesale    3776.23     2010
# 60       Wheat flour     Retail      98.69     4782
#
# [61 rows x 4 columns]

# %%
df[df['admin1'].isnull()]
# Out:
#             date admin1 admin2             market  market_id  latitude  \
# 2393  2015-01-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2421  2015-02-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2548  2015-06-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2580  2015-07-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2615  2015-08-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2643  2015-09-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2678  2015-10-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2709  2015-11-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2734  2015-12-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2766  2016-01-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2798  2016-02-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2836  2016-03-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2880  2016-05-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 2976  2016-08-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3009  2016-09-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3041  2016-10-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3102  2016-12-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3131  2017-01-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3200  2017-03-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3270  2017-05-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3301  2017-06-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3390  2017-09-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3427  2017-10-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3460  2017-11-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3525  2018-01-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3550  2018-02-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3584  2018-03-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3622  2018-04-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3690  2018-06-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3724  2018-07-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3825  2018-10-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3893  2018-12-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3932  2019-01-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 3967  2019-02-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4004  2019-03-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4040  2019-04-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4143  2019-07-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4177  2019-08-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4198  2019-09-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4231  2019-10-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4281  2019-12-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4381  2020-05-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4398  2020-06-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4417  2020-07-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4436  2020-08-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4457  2020-09-15    NaN    NaN  Hola (Tana River)       1854       NaN
# 4465  2020-10-15    NaN    NaN  Hola (Tana River)       1854       NaN
#
#       longitude            category      commodity  commodity_id unit  \
# 2393        NaN  cereals and tubers  Maize (white)            67   KG
# 2421        NaN  cereals and tubers  Maize (white)            67   KG
# 2548        NaN  cereals and tubers  Maize (white)            67   KG
# 2580        NaN  cereals and tubers  Maize (white)            67   KG
# 2615        NaN  cereals and tubers  Maize (white)            67   KG
# 2643        NaN  cereals and tubers  Maize (white)            67   KG
# 2678        NaN  cereals and tubers  Maize (white)            67   KG
# 2709        NaN  cereals and tubers  Maize (white)            67   KG
# 2734        NaN  cereals and tubers  Maize (white)            67   KG
# 2766        NaN  cereals and tubers  Maize (white)            67   KG
# 2798        NaN  cereals and tubers  Maize (white)            67   KG
# 2836        NaN  cereals and tubers  Maize (white)            67   KG
# 2880        NaN  cereals and tubers  Maize (white)            67   KG
# 2976        NaN  cereals and tubers  Maize (white)            67   KG
# 3009        NaN  cereals and tubers  Maize (white)            67   KG
# 3041        NaN  cereals and tubers  Maize (white)            67   KG
# 3102        NaN  cereals and tubers  Maize (white)            67   KG
# 3131        NaN  cereals and tubers  Maize (white)            67   KG
# 3200        NaN  cereals and tubers  Maize (white)            67   KG
# 3270        NaN  cereals and tubers  Maize (white)            67   KG
# 3301        NaN  cereals and tubers  Maize (white)            67   KG
# 3390        NaN  cereals and tubers  Maize (white)            67   KG
# 3427        NaN  cereals and tubers  Maize (white)            67   KG
# 3460        NaN  cereals and tubers  Maize (white)            67   KG
# 3525        NaN  cereals and tubers  Maize (white)            67   KG
# 3550        NaN  cereals and tubers  Maize (white)            67   KG
# 3584        NaN  cereals and tubers  Maize (white)            67   KG
# 3622        NaN  cereals and tubers  Maize (white)            67   KG
# 3690        NaN  cereals and tubers  Maize (white)            67   KG
# 3724        NaN  cereals and tubers  Maize (white)            67   KG
# 3825        NaN  cereals and tubers  Maize (white)            67   KG
# 3893        NaN  cereals and tubers  Maize (white)            67   KG
# 3932        NaN  cereals and tubers  Maize (white)            67   KG
# 3967        NaN  cereals and tubers  Maize (white)            67   KG
# 4004        NaN  cereals and tubers  Maize (white)            67   KG
# 4040        NaN  cereals and tubers  Maize (white)            67   KG
# 4143        NaN  cereals and tubers  Maize (white)            67   KG
# 4177        NaN  cereals and tubers  Maize (white)            67   KG
# 4198        NaN  cereals and tubers  Maize (white)            67   KG
# 4231        NaN  cereals and tubers  Maize (white)            67   KG
# 4281        NaN  cereals and tubers  Maize (white)            67   KG
# 4381        NaN  cereals and tubers  Maize (white)            67   KG
# 4398        NaN  cereals and tubers  Maize (white)            67   KG
# 4417        NaN  cereals and tubers  Maize (white)            67   KG
# 4436        NaN  cereals and tubers  Maize (white)            67   KG
# 4457        NaN  cereals and tubers  Maize (white)            67   KG
# 4465        NaN  cereals and tubers  Maize (white)            67   KG
#
#      priceflag pricetype currency  price  usdprice
# 2393    actual    Retail      KES  35.00      0.38
# 2421    actual    Retail      KES  35.00      0.38
# 2548    actual    Retail      KES  36.00      0.37
# 2580    actual    Retail      KES  42.00      0.41
# 2615    actual    Retail      KES  41.00      0.40
# 2643    actual    Retail      KES  39.25      0.37
# 2678    actual    Retail      KES  31.25      0.30
# 2709    actual    Retail      KES  44.47      0.43
# 2734    actual    Retail      KES  42.50      0.42
# 2766    actual    Retail      KES  39.17      0.38
# 2798    actual    Retail      KES  39.38      0.39
# 2836    actual    Retail      KES  38.35      0.38
# 2880    actual    Retail      KES  41.67      0.41
# 2976    actual    Retail      KES  53.45      0.53
# 3009    actual    Retail      KES  54.00      0.53
# 3041    actual    Retail      KES  58.00      0.57
# 3102    actual    Retail      KES  50.00      0.49
# 3131    actual    Retail      KES  53.20      0.51
# 3200    actual    Retail      KES  57.30      0.56
# 3270    actual    Retail      KES  60.00      0.58
# 3301    actual    Retail      KES  80.00      0.78
# 3390    actual    Retail      KES  64.00      0.62
# 3427    actual    Retail      KES  60.00      0.58
# 3460    actual    Retail      KES  50.83      0.49
# 3525    actual    Retail      KES  55.00      0.53
# 3550    actual    Retail      KES  55.00      0.54
# 3584    actual    Retail      KES  58.00      0.57
# 3622    actual    Retail      KES  50.00      0.50
# 3690    actual    Retail      KES  57.00      0.56
# 3724    actual    Retail      KES  55.00      0.55
# 3825    actual    Retail      KES  55.30      0.55
# 3893    actual    Retail      KES  42.00      0.41
# 3932    actual    Retail      KES  63.00      0.62
# 3967    actual    Retail      KES  64.00      0.64
# 4004    actual    Retail      KES  54.00      0.54
# 4040    actual    Retail      KES  51.00      0.51
# 4143    actual    Retail      KES  59.30      0.58
# 4177    actual    Retail      KES  56.80      0.55
# 4198    actual    Retail      KES  52.20      0.50
# 4231    actual    Retail      KES  40.00      0.39
# 4281    actual    Retail      KES  66.00      0.65
# 4381    actual    Retail      KES  66.00      0.62
# 4398    actual    Retail      KES  57.00      0.53
# 4417    actual    Retail      KES  57.00      0.53
# 4436    actual    Retail      KES  66.00      0.61
# 4457    actual    Retail      KES  55.00      0.51
# 4465    actual    Retail      KES  53.00      0.49

# %%
df[df['admin1'].isnull()]['market'].unique()
# Out:
# <StringArray>
# ['Hola (Tana River)']
# Length: 1, dtype: str

# %%
df.loc[df['market'] == 'Hola (Tana River)', 'admin1'] = 'Tana River'
df.loc[df['market'] == 'Hola (Tana River)', 'admin2'] = 'Tana River'
df.loc[df['market'] == 'Hola (Tana River)', 'latitude'] = -1.0
df.loc[df['market'] == 'Hola (Tana River)', 'longitude'] = 40.0

# %%
df[df['market'] == 'Hola (Tana River)'].isnull().sum()
# Out:
# date            0
# admin1          0
# admin2          0
# market          0
# market_id       0
# latitude        0
# longitude       0
# category        0
# commodity       0
# commodity_id    0
# unit            0
# priceflag       0
# pricetype       0
# currency        0
# price           0
# usdprice        0
# dtype: int64

# %%
df['pricetype'].unique()
# Out:
# <StringArray>
# ['Wholesale', 'Retail']
# Length: 2, dtype: str

# %%
df['date'].head()
# Out:
# 0   2006-01-15
# 1   2006-01-15
# 2   2006-01-15
# 3   2006-01-15
# 4   2006-01-15
# Name: date, dtype: datetime64[us]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date'].head()
# Out:
# 0   2006-01-15
# 1   2006-01-15
# 2   2006-01-15
# 3   2006-01-15
# 4   2006-01-15
# Name: date, dtype: datetime64[us]

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
df[['date', 'year', 'month']].tail()
# Out:
#             date  year  month
# 17627 2025-11-15  2025     11
# 17628 2025-11-15  2025     11
# 17629 2025-11-15  2025     11
# 17630 2025-11-15  2025     11
# 17631 2025-11-15  2025     11

# %%
df['unit'].unique()
# Out:
# <StringArray>
# [    'KG',  '400 G',  '90 KG',  '50 KG', '500 ML',      'L', '200 ML',
#    'Unit',  'Bunch', '126 KG',  '13 KG',  '64 KG',  '200 G',   'Head']
# Length: 14, dtype: str

# %%
df[df['unit'] == 'Head']
# Out:
#             date         admin1   admin2                 market  market_id  \
# 12198 2021-01-15          Coast  Mombasa     Kalahari (Mombasa)       4239
# 12212 2021-01-15        Nairobi  Nairobi      Kangemi (Nairobi)       4626
# 12219 2021-01-15        Nairobi  Nairobi   Kawangware (Nairobi)       4625
# 12245 2021-01-15  North Eastern  Garissa     Dagahaley (Daadab)       3252
# 12256 2021-01-15  North Eastern  Garissa      Hagadera (Daadab)       3254
# 12263 2021-01-15    Rift Valley  Turkana  Kalobeyei (Village 1)       3244
# 12281 2021-01-15    Rift Valley  Turkana  Kalobeyei (Village 3)       3247
# 12290 2021-02-15        Eastern   Isiolo            Isiolo town       3262
# 12318 2021-02-15        Nairobi  Nairobi      Kangemi (Nairobi)       4626
# 12331 2021-02-15        Nairobi  Nairobi   Kawangware (Nairobi)       4625
# 12345 2021-02-15        Nairobi  Nairobi        Kibra (Nairobi)       4627
# 12355 2021-02-15        Nairobi  Nairobi      Mathare (Nairobi)       4624
# 12376 2021-02-15  North Eastern    Wajir             Wajir town       3271
# 12408 2021-02-15    Rift Valley  Turkana               Kakuma 2       3248
# 12415 2021-02-15    Rift Valley  Turkana               Kakuma 3       3251
# 12423 2021-02-15    Rift Valley  Turkana               Kakuma 4       3249
# 12439 2021-02-15    Rift Valley  Turkana  Kalobeyei (Village 2)       3246
# 12450 2021-02-15    Rift Valley  Turkana            Lodwar town       3360
#
#        latitude  longitude               category commodity  commodity_id  \
# 12198     -4.03      39.63  vegetables and fruits   Cabbage           181
# 12212     -1.27      36.74  vegetables and fruits   Cabbage           181
# 12219     -1.28      36.74  vegetables and fruits   Cabbage           181
# 12245      0.19      40.29  vegetables and fruits   Cabbage           181
# 12256      0.01      40.37  vegetables and fruits   Cabbage           181
# 12263      3.77      34.73  vegetables and fruits   Cabbage           181
# 12281      3.75      34.76  vegetables and fruits   Cabbage           181
# 12290      0.35      37.58  vegetables and fruits   Cabbage           181
# 12318     -1.27      36.74  vegetables and fruits   Cabbage           181
# 12331     -1.28      36.74  vegetables and fruits   Cabbage           181
# 12345     -1.32      36.78  vegetables and fruits   Cabbage           181
# 12355     -1.26      36.86  vegetables and fruits   Cabbage           181
# 12376      1.75      40.06  vegetables and fruits   Cabbage           181
# 12408      3.75      34.82  vegetables and fruits   Cabbage           181
# 12415      3.77      34.82  vegetables and fruits   Cabbage           181
# 12423      3.74      34.81  vegetables and fruits   Cabbage           181
# 12439      3.76      34.75  vegetables and fruits   Cabbage           181
# 12450      3.12      35.60  vegetables and fruits   Cabbage           181
#
#        unit  priceflag pricetype currency   price  usdprice  year  month
# 12198  Head  aggregate    Retail      KES   50.00      0.45  2021      1
# 12212  Head  aggregate    Retail      KES   40.00      0.36  2021      1
# 12219  Head  aggregate    Retail      KES   40.00      0.36  2021      1
# 12245  Head  aggregate    Retail      KES  120.00      1.09  2021      1
# 12256  Head  aggregate    Retail      KES  110.00      1.00  2021      1
# 12263  Head  aggregate    Retail      KES   70.00      0.64  2021      1
# 12281  Head  aggregate    Retail      KES   80.00      0.73  2021      1
# 12290  Head  aggregate    Retail      KES   42.50      0.39  2021      2
# 12318  Head  aggregate    Retail      KES   27.46      0.25  2021      2
# 12331  Head  aggregate    Retail      KES   30.00      0.27  2021      2
# 12345  Head  aggregate    Retail      KES   31.22      0.29  2021      2
# 12355  Head  aggregate    Retail      KES   32.22      0.29  2021      2
# 12376  Head  aggregate    Retail      KES  130.83      1.20  2021      2
# 12408  Head  aggregate    Retail      KES   70.00      0.64  2021      2
# 12415  Head  aggregate    Retail      KES   73.33      0.67  2021      2
# 12423  Head  aggregate    Retail      KES   65.00      0.59  2021      2
# 12439  Head  aggregate    Retail      KES   70.00      0.64  2021      2
# 12450  Head  aggregate    Retail      KES  100.00      0.91  2021      2

# %%
df['Unit'] == 'KG'
